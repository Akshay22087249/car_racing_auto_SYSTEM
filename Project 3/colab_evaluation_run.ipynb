# %%
# !pip install pettingzoo[atari] autorom stable-baselines3
# !AutoROM --accept-license
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 707.8/707.8 kB 18.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 75.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.5/805.5 kB 28.1 MB/s eta 0:00:00
# ...
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	/usr/local/lib/python3.12/dist-packages/AutoROM/roms
# 	/usr/local/lib/python3.12/dist-packages/multi_agent_ale_py/roms
#
# Existing ROMs will be overwritten.
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/adventure.bin
# Installed /usr/local/lib/python3.12/dist-packages/multi_agent_ale_py/roms/adventure.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/air_raid.bin
# Installed /usr/local/lib/python3.12/dist-packages/multi_agent_ale_py/roms/air_raid.bin
# Installed /usr/local/lib/python3.12/dist-packages/AutoROM/roms/alien.bin
# ...

# %%
from google.colab import files
uploaded = files.upload()  # selecteer p3.zip
# Out:
#      <input type="file" id="files-a866b14f-77e4-4e3a-a35a-7f74facb9efc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a866b14f-77e4-4e3a-a35a-7f74facb9efc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile, os
with zipfile.ZipFile('Project 3.zip', 'r') as z:
    z.extractall('.')
os.chdir('Project 3')
print(os.listdir('.'))
# Out:
# ['calib.py', 'requirements.txt', 'tourney.py', 'train_solo.py', 'run_optimization.py', 'evaluate.py', 'results', 'agents', 'ram_map.py', '.venv311', 'bench_final.py', '.venv313', 'optimize.py', 'export_policy.py', 'README.md', 'models', 'report', 'train.py', 'warlords_solo.py', 'make_stall_video.py', 'bakeoff.py', 'baselines.py', 'Project description_docs', '__pycache__', 'probe_truth.py', 'measure.py', 'warlords_env.py', 'FINDINGS.md', 'evaluate_final.py', 'controllers.py', '.venv', 'rescan.py']

# %%
# !python run_optimization.py --procs 2 --fast
# Out:
# FAST mode: minder nauwkeurig maar sneller (~5-10 min per corner)
#
# ...
# Corner 0 tuning: 20 kandidaten, 12 screen-games, 20 refine-games, 2 processen
# ...
#
# Corner 0 — top 5 (params | win | timeout):
#   (0.604, -0.468, -0.319, -2.824, 1.31)  win=0.350  to=0.00
#   (0.432, -0.229, 0.176, -3.712, 1.416)  win=0.300  to=0.00
#   (0.686, 0.16, 0.044, -3.38, 1.758)  win=0.250  to=0.05
#   (0.796, -0.962, -0.424, -3.347, 2.388)  win=0.200  to=0.00
#   (0.5, 1.0, -1.0, 0.0, 0.0)  win=0.200  to=0.20
#
# → Beste: (0.604, -0.468, -0.319, -2.824, 1.31)  win=0.350  timeout=0.00
#   Tijd: 42.6 minuten
#
#   best_params.json bijgewerkt met corner 0
#
# ...
# Corner 1 tuning: 20 kandidaten, 12 screen-games, 20 refine-games, 2 processen
# ...
#
# Corner 1 — top 5 (params | win | timeout):
#   (0.247, 1.883, -1.483, -1.226, -1.927)  win=0.450  to=0.05
#   (0.247, 1.883, -1.483, -1.226, -1.927)  win=0.450  to=0.05
#   (0.5, 1.0, -1.0, 0.0, 0.0)  win=0.200  to=0.00
# ...

# %%
# !python evaluate_final.py --games 20
# Out:
# Finale evaluatie: 20 games/seat, seats=(0, 1, 2, 3), max_cycles=100000
#
# Agent           |    Win   Loss  Timeout |  Survival
# ----------------------------------------------------------
# random          |  0.250  0.750    0.000 |      5116
# rule_agent      |  0.237  0.762    0.000 |      5734
# ppo_agent       |  0.125  0.500    0.375 |     40561
# tuned_agent     |  0.237  0.750    0.013 |      6829
#
# CSV opgeslagen: /content/Project 3/results/final_comparison.csv
# Grafiek opgeslagen: /content/Project 3/results/final_comparison.png

# %%
from google.colab import files
files.download('best_params.json')
files.download('results/final_comparison.png')
files.download('results/final_comparison.csv')

# %%
# !python evaluate_final.py --games 40
# Out:
# Finale evaluatie: 40 games/seat, seats=(0, 1, 2, 3), max_cycles=100000
#
# Agent           |    Win   Loss  Timeout |  Survival
# ----------------------------------------------------------
# random          |  0.250  0.750    0.000 |      5032
# rule_agent      |  0.263  0.738    0.000 |      5748
# ppo_agent       |  0.113  0.494    0.394 |     42982
# tuned_agent     |  0.287  0.694    0.019 |      7308
#
# CSV opgeslagen: /content/Project 3/results/final_comparison.csv
# Grafiek opgeslagen: /content/Project 3/results/final_comparison.png

# %%
+
----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------from google.colab import files
files.download('best_params.json')
files.download('results/final_comparison.png')
files.download('results/final_comparison.csv')
